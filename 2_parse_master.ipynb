# %% [markdown]
# # KAKENの各種マスタをローカルのDBに保存する

# %% [markdown]
# ## 事前準備

# %% [markdown]
# - KAKENマスタデータは、git のリポジトリで管理されており、最新のデータを利用可能。https://bitbucket.org/niijp/grants_masterxml_kaken/ からリポジトリを pull して、ローカルの ./grants_masterxml_kaken フォルダに同期しておく。

# %% [markdown]
# 1. 研究種目：category_master_kakenhi.xml
# 2. 研究分野：field_master_kakenhi.xml
# 3. 研究機関：institution_master_kakenhi.xml
# 4. 審査区分：review_section_master_kakenhi.xml
# 5. 応募区分：section_master_kakenhi.xml

# %%
import configparser

import numpy as np
import pandas as pd
import pymysql
from lxml import etree
from sqlalchemy import create_engine
from sqlalchemy.types import Date, Integer, String, Text

# %%
config = configparser.ConfigParser()
config.read("../kaken_parse_grants_masterxml/config.ini")
username = config["mariadb"]["username"]
password = config["mariadb"]["password"]
url = (
    "mysql+pymysql://"
    + username
    + ":"
    + password
    + "@localhost:3306/"
    + "kaken"
    + "?charset=UTF8MB4"
)
engine = create_engine(url, echo=True)

# %% [markdown]
# ## 1. 研究種目マスタ

# %%
# XMLファイルからリストを作成する
tree = etree.parse("../grants_masterxml_kaken/category_master_kakenhi.xml")
categorylist = []
for category_table in tree.iterfind("category_table"):
    for category in category_table.iterfind("category"):
        name = category.find("name[@lang='ja']").text
        niicode = category.find("code[@type='nii']").text
        row = [niicode, name]
        categorylist.append(row)
# リストをデータフレームに変換する
columns = ["category_niicode", "category_name"]
df = pd.DataFrame(categorylist, columns=columns)
# 重複を削除して、category_niicodeに重複がないことを確認して、インデックスに設定する
df = df.drop_duplicates()
assert not df["category_niicode"].duplicated().any(), "category_niicode is duplicated."
df = df.set_index("category_niicode")
df
# Out:
#                                  category_name
# category_niicode
# 1                                         機関研究
# 2                                         各個研究
# 3                                         特定研究
# 4                                         総合研究
# 5                                         試験研究
# 6                                       海外学術調査
# 7                                      研究成果刊行費
# 8                                         奨励研究
# 9                                       がん特別研究
# 10                                     総合研究(A)
# 11                                     総合研究(B)
# 12                                     一般研究(A)
# 13                                     一般研究(B)
# 14                                     一般研究(C)
# 15                                     一般研究(D)
# 16                                        一般研究
# 17                                     奨励研究(A)
# 18                                     奨励研究(B)
# 19                                    自然災害特別研究
# 20                                      海外学術調査
# 21                                     研究成果刊行費
# 22                                      海外学術調査
# 23                                    環境科学特別研究
# 24                                     特別研究促進費
# 25                            エネルギー特別研究(エネルギー)
# 26                              エネルギー特別研究(核融合)
# 28                                      特別推進研究
# 29                                      海外学術調査
# 30                                      海外学術調査
# 31                                     研究成果刊行費
# ...                                        ...
# 55                                     特別研究促進費
# 56                                   地域連携推進研究費
# 57                                   特定領域研究(C)
# 58                                     基盤研究(A)
# 59                                     基盤研究(B)
# 60                                     基盤研究(S)
# 61                                 特別推進研究(COE)
# 62                                      特定領域研究
# 63                                        奨励研究
# 64                                     若手研究(A)
# 65                                     若手研究(B)
# 66                                        萌芽研究
# 67                                     学術創成研究費
# 68                                     基盤研究(A)
# 69                                     基盤研究(B)
# 70                               若手研究(スタートアップ)
# 71                                     若手研究(S)
# 72                                     基盤研究(C)
# 73                            新学術領域研究(研究領域提案型)
# 74                            新学術領域研究(研究課題提案型)
# 75                                     挑戦的萌芽研究
# 76                                  研究活動スタート支援
# 77                        国際共同研究加速基金(国際共同研究強化)
# 79                          国際共同研究加速基金(帰国発展研究)
# 247               新学術領域研究（研究領域提案型）『学術研究支援基盤形成』
# 249                                  挑戦的研究(開拓)
# 250                                  挑戦的研究(萌芽)
# 252                                       若手研究
# 253                    国際共同研究加速基金(国際共同研究強化(B))
# 254                    国際共同研究加速基金(国際共同研究強化(A))
#
# [82 rows x 1 columns]

# %%
# 外部キー制約を外す
try:
    with engine.connect() as con:
        con.execute("ALTER TABLE grantaward DROP FOREIGN KEY category_niicode_1;")
except:
    pass
# データベースに書き込む
df.to_sql(
    "categories",
    engine,
    if_exists="replace",
    dtype={"category_niicode": Integer, "category_name": String(255)},
)
# Out:
# 2020-05-23 09:24:35,432 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-05-23 09:24:35,433 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,439 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-05-23 09:24:35,440 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,443 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8' and `Collation` = 'utf8_bin'
# 2020-05-23 09:24:35,444 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,449 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-05-23 09:24:35,450 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,452 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2020-05-23 09:24:35,453 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,455 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8) COLLATE utf8_bin AS anon_1
# 2020-05-23 09:24:35,457 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,461 INFO sqlalchemy.engine.base.Engine ALTER TABLE grantaward DROP FOREIGN KEY category_niicode_1;
# 2020-05-23 09:24:35,462 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,467 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:35,473 INFO sqlalchemy.engine.base.Engine DESCRIBE `categories`
# 2020-05-23 09:24:35,474 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,479 INFO sqlalchemy.engine.base.Engine DESCRIBE `categories`
# 2020-05-23 09:24:35,480 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,484 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `kaken`
# 2020-05-23 09:24:35,485 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,519 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `categories`
# 2020-05-23 09:24:35,520 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,523 INFO sqlalchemy.engine.base.Engine
# DROP TABLE categories
# 2020-05-23 09:24:35,525 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,528 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:35,531 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE categories (
# 	category_niicode INTEGER,
# 	category_name VARCHAR(255)
# )
#
#
# 2020-05-23 09:24:35,531 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,547 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:35,548 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_categories_category_niicode ON categories (category_niicode)
# 2020-05-23 09:24:35,549 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:35,553 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:35,557 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-23 09:24:35,560 INFO sqlalchemy.engine.base.Engine INSERT INTO categories (category_niicode, category_name) VALUES (%(category_niicode)s, %(category_name)s)
# 2020-05-23 09:24:35,561 INFO sqlalchemy.engine.base.Engine ({'category_niicode': '1', 'category_name': '機関研究'}, {'category_niicode': '2', 'category_name': '各個研究'}, {'category_niicode': '3', 'category_name': '特定研究'}, {'category_niicode': '4', 'category_name': '総合研究'}, {'category_niicode': '5', 'category_name': '試験研究'}, {'category_niicode': '6', 'category_name': '海外学術調査'}, {'category_niicode': '7', 'category_name': '研究成果刊行費'}, {'category_niicode': '8', 'category_name': '奨励研究'}  ... displaying 10 of 82 total bound parameter sets ...  {'category_niicode': '253', 'category_name': '国際共同研究加速基金(国際共同研究強化(B))'}, {'category_niicode': '254', 'category_name': '国際共同研究加速基金(国際共同研究強化(A))'})
# 2020-05-23 09:24:35,566 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ## 2. 研究分野マスタ

# %%
# XMLファイルからリストを作成する
tree = etree.parse("../grants_masterxml_kaken/field_master_kakenhi.xml")
fieldlist = []
for field_table in tree.iterfind("field_table"):
    field_table_type = field_table.get("type")
    field_table_start_date = field_table.get("start_date")
    field_table_end_date = field_table.get("end_date")
    # layer 1
    for field in field_table.iterfind("field"):
        field_path = field.get("path")
        field_niicode = field.find("code[@type='nii']").text
        field_name = field.find("name[@lang='ja']").text
        row = [
            field_table_type,
            field_table_start_date,
            field_table_end_date,
            field_path,
            field_niicode,
            field_name,
            1,
        ]
        fieldlist.append(row)
        # layer 2
        for field in field.iterfind("field"):
            field_path = field.get("path")
            field_niicode = field.find("code[@type='nii']").text
            field_name = field.find("name[@lang='ja']").text
            row = [
                field_table_type,
                field_table_start_date,
                field_table_end_date,
                field_path,
                field_niicode,
                field_name,
                2,
            ]
            fieldlist.append(row)
            # layer 3
            for field in field.iterfind("field"):
                field_path = field.get("path")
                field_niicode = field.find("code[@type='nii']").text
                field_name = field.find("name[@lang='ja']").text
                row = [
                    field_table_type,
                    field_table_start_date,
                    field_table_end_date,
                    field_path,
                    field_niicode,
                    field_name,
                    3,
                ]
                fieldlist.append(row)
                # layer 4
                for field in field.iterfind("field"):
                    field_path = field.get("path")
                    field_niicode = field.find("code[@type='nii']").text
                    field_name = field.find("name[@lang='ja']").text
                    row = [
                        field_table_type,
                        field_table_start_date,
                        field_table_end_date,
                        field_path,
                        field_niicode,
                        field_name,
                        4,
                    ]
                    fieldlist.append(row)
# リストをデータフレームに変換する
columns = [
    "field_table_type",
    "field_table_start_date",
    "field_table_end_date",
    "field_path",
    "field_niicode",
    "field_name",
    "layer",
]
df = pd.DataFrame(fieldlist, columns=columns)
df
# Out:
#      field_table_type field_table_start_date field_table_end_date  \
# 0             saimoku             1972-04-01           1973-03-31
# 1             saimoku             1972-04-01           1973-03-31
# 2             saimoku             1972-04-01           1973-03-31
# 3             saimoku             1972-04-01           1973-03-31
# 4             saimoku             1972-04-01           1973-03-31
# 5             saimoku             1972-04-01           1973-03-31
# 6             saimoku             1972-04-01           1973-03-31
# 7             saimoku             1972-04-01           1973-03-31
# 8             saimoku             1972-04-01           1973-03-31
# 9             saimoku             1972-04-01           1973-03-31
# 10            saimoku             1972-04-01           1973-03-31
# 11            saimoku             1972-04-01           1973-03-31
# 12            saimoku             1972-04-01           1973-03-31
# 13            saimoku             1972-04-01           1973-03-31
# 14            saimoku             1972-04-01           1973-03-31
# 15            saimoku             1972-04-01           1973-03-31
# 16            saimoku             1972-04-01           1973-03-31
# 17            saimoku             1972-04-01           1973-03-31
# 18            saimoku             1972-04-01           1973-03-31
# 19            saimoku             1972-04-01           1973-03-31
# 20            saimoku             1972-04-01           1973-03-31
# 21            saimoku             1972-04-01           1973-03-31
# 22            saimoku             1972-04-01           1973-03-31
# 23            saimoku             1972-04-01           1973-03-31
# 24            saimoku             1972-04-01           1973-03-31
# 25            saimoku             1972-04-01           1973-03-31
# 26            saimoku             1972-04-01           1973-03-31
# 27            saimoku             1972-04-01           1973-03-31
# 28            saimoku             1972-04-01           1973-03-31
# 29            saimoku             1972-04-01           1973-03-31
# ...               ...                    ...                  ...
# 9166     zantei_bunya             2017-04-01           2018-03-31
# 9167     zantei_bunya             2017-04-01           2018-03-31
# 9168     zantei_bunya             2017-04-01           2018-03-31
# 9169     zantei_bunya             2017-04-01           2018-03-31
# 9170     zantei_bunya             2017-04-01           2018-03-31
# 9171     zantei_bunya             2017-04-01           2018-03-31
# 9172     zantei_bunya             2017-04-01           2018-03-31
# 9173     zantei_bunya             2017-04-01           2018-03-31
# 9174     zantei_bunya             2017-04-01           2018-03-31
# 9175     zantei_bunya             2017-04-01           2018-03-31
# 9176     zantei_bunya             2017-04-01           2018-03-31
# 9177     zantei_bunya             2017-04-01           2018-03-31
# 9178     zantei_bunya             2017-04-01           2018-03-31
# 9179     zantei_bunya             2017-04-01           2018-03-31
# 9180     zantei_bunya             2017-04-01           2018-03-31
# 9181     zantei_bunya             2017-04-01           2018-03-31
# 9182     zantei_bunya             2017-04-01           2018-03-31
# 9183     zantei_bunya             2017-04-01           2018-03-31
# 9184     zantei_bunya             2017-04-01           2018-03-31
# 9185     zantei_bunya             2017-04-01           2018-03-31
# 9186     zantei_bunya             2017-04-01           2018-03-31
# 9187     zantei_bunya             2017-04-01           2018-03-31
# 9188     zantei_bunya             2017-04-01           2018-03-31
# 9189     zantei_bunya             2017-04-01           2018-03-31
# 9190     zantei_bunya             2017-04-01           2018-03-31
# 9191     zantei_bunya             2017-04-01           2018-03-31
# 9192     zantei_bunya             2017-04-01           2018-03-31
# 9193     zantei_bunya             2017-04-01           2018-03-31
# 9194     zantei_bunya             2017-04-01           2018-03-31
# 9195     zantei_bunya             2017-04-01           2018-03-31
#
#               field_path field_niicode                 field_name  layer
# 0                 000001             1                         文学      1
# 1           000001000002             2                         哲学      2
# 2     000001000002000003             3                         哲学      3
# 3     000001000002000004             4                       中国哲学      3
# 4     000001000002000005             5                 印度哲学(含仏教学)      3
# 5     000001000002000006             6                        宗教学      3
# 6     000001000002000007             7                        倫理学      3
# 7     000001000002000008             8                  美学(含芸術諸学)      3
# 8     000001000002000009             9                        美術史      3
# 9           000001000010            10          心理学・社会学・教育学・文化人類学      2
# 10    000001000010000011            11                        心理学      3
# 11    000001000010000012            12                        社会学      3
# 12    000001000010000013            13                        教育学      3
# 13    000001000010000014            14            文化人類学(含民族学・民俗学)      3
# 14          000001000015            15                         史学      2
# 15    000001000015000016            16                        日本史      3
# 16    000001000015000017            17                        東洋史      3
# 17    000001000015000018            18                        西洋史      3
# 18    000001000015000019            19                  考古学(含先史学)      3
# 19          000001000020            20                         文学      2
# 20    000001000020000021            21                        国語学      3
# 21    000001000020000022            22                        国文学      3
# 22    000001000020000023            23                   中国語・中国文学      3
# 23    000001000020000024            24      英語・英文学(含アメリカ語･アメリカ文学)      3
# 24    000001000020000025            25                     仏語・仏文学      3
# 25    000001000020000026            26                     独語・独文学      3
# 26    000001000020000027            27               その他の外国語・外国文学      3
# 27    000001000020000028            28                  言語学(含音声学)      3
# 28    000001000020000029            29       文学一般(含文学論・比較文学・西洋古典)      3
# 29                000030            30                         法学      1
# ...                  ...           ...                        ...    ...
# 9166              003080          3080  無機材料化学、エネルギー関連化学およびその関連分野      1
# 9167              003081          3081            生体分子化学およびその関連分野      1
# 9168              003082          3082              農芸化学およびその関連分野      1
# 9169              003083          3083            生産環境農学およびその関連分野      1
# 9170              003084          3084      森林圏科学、水圏応用科学およびその関連分野      1
# 9171              003085          3085       社会経済農学、農業工学およびその関連分野      1
# 9172              003086          3086           獣医学、畜産学およびその関連分野      1
# 9173              003087          3087             分子生物学およびその関連分野      1
# 9174              003088          3088  細胞レベルから個体レベルの生物学およびその関連分野      1
# 9175              003089          3089        多様性生物学、人類学およびその関連分野      1
# 9176              003090          3090              神経科学およびその関連分野      1
# 9177              003091          3091                薬学およびその関連分野      1
# 9178              003092          3092          生体の構造と機能およびその関連分野      1
# 9179              003093          3093      病理病態学、感染・免疫学およびその関連分野      1
# 9180              003094          3094               腫瘍学およびその関連分野      1
# 9181              003095          3095         ブレインサイエンスおよびその関連分野      1
# 9182              003096          3096             内科学一般およびその関連分野      1
# 9183              003097          3097         器官システム内科学およびその関連分野      1
# 9184              003098          3098           生体情報内科学およびその関連分野      1
# 9185              003099          3099       恒常性維持器官の外科学およびその関連分野      1
# 9186              003100          3100  生体機能および感覚に関する外科学およびその関連分野      1
# 9187              003101          3101              口腔科学およびその関連分野      1
# 9188              003102          3102          社会医学、看護学およびその関連分野      1
# 9189              003103          3103              健康科学およびその関連分野      1
# 9190              003104          3104         情報科学、情報工学およびその関連分野      1
# 9191              003105          3105             人間情報学およびその関連分野      1
# 9192              003106          3106             応用情報学およびその関連分野      1
# 9193              003107          3107            環境解析評価およびその関連分野      1
# 9194              003108          3108            環境保全対策およびその関連分野      1
# 9195              003109          3109             人間医工学およびその関連分野      1
#
# [9196 rows x 7 columns]

# %%
# 外部キー制約を外す
try:
    with engine.connect() as con:
#        con.execute("ALTER TABLE grantaward DROP FOREIGN KEY field_niicode_1;")
        con.execute("ALTER TABLE grantaward_field DROP FOREIGN KEY fk_grantaward_field_field_niicode;")
        con.execute("ALTER TABLE grantaward_field DROP FOREIGN KEY fk_grantaward_field_field_path;")
except:
    pass
# データベースに書き込む
df.to_sql(
    "fields",
    engine,
    if_exists="replace",
    dtype={
        "field_table_type": String(255),
        "field_table_start_date": Date,
        "field_table_end_date": Date,
        "field_path": String(255),
        "field_niicode": Integer,
        "field_name": String(255),
        "layer": Integer,
    },
)
# Out:
# 2020-05-23 09:24:57,287 INFO sqlalchemy.engine.base.Engine ALTER TABLE grantaward_field DROP FOREIGN KEY fk_grantaward_field_field_niicode;
# 2020-05-23 09:24:57,288 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,295 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-05-23 09:24:57,299 INFO sqlalchemy.engine.base.Engine DESCRIBE `fields`
# 2020-05-23 09:24:57,300 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,303 INFO sqlalchemy.engine.base.Engine DESCRIBE `fields`
# 2020-05-23 09:24:57,304 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,309 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `kaken`
# 2020-05-23 09:24:57,310 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,313 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `fields`
# 2020-05-23 09:24:57,314 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,320 INFO sqlalchemy.engine.base.Engine
# DROP TABLE `fields`
# 2020-05-23 09:24:57,321 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,327 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:57,331 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE `fields` (
# 	`index` BIGINT,
# 	field_table_type VARCHAR(255),
# 	field_table_start_date DATE,
# 	field_table_end_date DATE,
# 	field_path VARCHAR(255),
# 	field_niicode INTEGER,
# 	field_name VARCHAR(255),
# 	layer INTEGER
# )
#
#
# 2020-05-23 09:24:57,332 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,350 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:57,352 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_fields_index ON `fields` (`index`)
# 2020-05-23 09:24:57,353 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:24:57,359 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:24:57,371 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-23 09:24:57,477 INFO sqlalchemy.engine.base.Engine INSERT INTO `fields` (`index`, field_table_type, field_table_start_date, field_table_end_date, field_path, field_niicode, field_name, layer) VALUES (%(index)s, %(field_table_type)s, %(field_table_start_date)s, %(field_table_end_date)s, %(field_path)s, %(field_niicode)s, %(field_name)s, %(layer)s)
# 2020-05-23 09:24:57,478 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001', 'field_niicode': '1', 'field_name': '文学', 'layer': 1}, {'index': 1, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002', 'field_niicode': '2', 'field_name': '哲学', 'layer': 2}, {'index': 2, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000003', 'field_niicode': '3', 'field_name': '哲学', 'layer': 3}, {'index': 3, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000004', 'field_niicode': '4', 'field_name': '中国哲学', 'layer': 3}, {'index': 4, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000005', 'field_niicode': '5', 'field_name': '印度哲学(含仏教学)', 'layer': 3}, {'index': 5, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000006', 'field_niicode': '6', 'field_name': '宗教学', 'layer': 3}, {'index': 6, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000007', 'field_niicode': '7', 'field_name': '倫理学', 'layer': 3}, {'index': 7, 'field_table_type': 'saimoku', 'field_table_start_date': '1972-04-01', 'field_table_end_date': '1973-03-31', 'field_path': '000001000002000008', 'field_niicode': '8', 'field_name': '美学(含芸術諸学)', 'layer': 3}  ... displaying 10 of 9196 total bound parameter sets ...  {'index': 9194, 'field_table_type': 'zantei_bunya', 'field_table_start_date': '2017-04-01', 'field_table_end_date': '2018-03-31', 'field_path': '003108', 'field_niicode': '3108', 'field_name': '環境保全対策およびその関連分野', 'layer': 1}, {'index': 9195, 'field_table_type': 'zantei_bunya', 'field_table_start_date': '2017-04-01', 'field_table_end_date': '2018-03-31', 'field_path': '003109', 'field_niicode': '3109', 'field_name': '人間医工学およびその関連分野', 'layer': 1})
# 2020-05-23 09:24:57,812 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# 主キーと外部キー制約を設定する
with engine.connect() as con:
    con.execute("ALTER TABLE fields ADD INDEX (field_niicode);")
    con.execute("ALTER TABLE fields ADD INDEX (field_path);")
# Out:
# 2020-05-23 09:25:35,429 INFO sqlalchemy.engine.base.Engine ALTER TABLE fields ADD INDEX (field_niicode);
# 2020-05-23 09:25:35,430 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:35,453 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:25:35,455 INFO sqlalchemy.engine.base.Engine ALTER TABLE fields ADD INDEX (field_path);
# 2020-05-23 09:25:35,457 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:35,483 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# # 3. 研究機関マスタ

# %%
# XMLファイルからリストを作成する
tree = etree.parse("../grants_masterxml_kaken/institution_master_kakenhi.xml")
institutionlist = []
for institution_table in tree.iterfind("institution_table"):
    for institution in institution_table.iterfind("institution"):
        institution_name_ja = institution.find("name[@lang='ja']").text
        institution_name_en = institution.find("name[@lang='en']").text
        institution_niicode = institution.find("code[@type='nii']").text
        institution_mextcode = institution.find("code[@type='mext']").text
        try:
            institution_jspscode = institution.find("code[@type='jsps']").text
        except AttributeError:
            institution_jspscode = None
        row = [
            institution_niicode,
            institution_mextcode,
            institution_jspscode,
            institution_name_ja,
            institution_name_en,
        ]
        institutionlist.append(row)
# リストからデータフレームに変換する
columns = [
    "institution_niicode",
    "institution_mextcode",
    "institution_jspscode",
    "institution_name_ja",
    "institution_name_en",
]
df = pd.DataFrame(institutionlist, columns=columns)
# 重複を削除して、category_niicodeに重複がないことを確認して、インデックスに設定する
df = df.drop_duplicates()
assert not df["institution_niicode"].duplicated().any(), "category_niicode is duplicated."
df = df.set_index("institution_niicode")
df
# Out:
#                     institution_mextcode institution_jspscode  \
# institution_niicode
# 0010101                            10101                10101
# 0010102                            10102                10102
# 0010103                            10103                10103
# 0010104                            10104                10104
# 0010105                            10105                10105
# 0010106                            10106                10106
# 0010107                            10107                10107
# 0011101                            11101                11101
# 0011201                            11201                11201
# 0011301                            11301                11301
# 0011302                            11302                11302
# 0011401                            11401                11401
# 0011501                            11501                11501
# 0011601                            11601                11601
# 0012101                            12101                12101
# 0012201                            12201                12201
# 0012301                            12301                12301
# 0012401                            12401                12401
# 0012501                            12501                12501
# 0012601                            12601                12601
# 0012602                            12602                12602
# 0012603                            12603                12603
# 0012604                            12604                12604
# 0012605                            12605                12605
# 0012606                            12606                12606
# 0012608                            12608                12608
# 0012610                            12610                 None
# 0012611                            12611                12611
# 0012612                            12612                12612
# 0012613                            12613                12613
# ...                                  ...                  ...
# 0062612                            62612                 None
# 0062613                            62613                 None
# 0062617                            62617                 None
# 0062701                            62701                 None
# 0062702                            62702                 None
# 0063901                            63901                 None
# 0064301                            64301                 None
# 0064402                            64402                 None
# 0064601                            64601                 None
# 0064602                            64602                 None
# 0081402                            81402                 None
# 0081403                            81403                 None
# 0082404                            82404                 None
# 0082605                            82605                 None
# 0082608                            82608                 None
# 0082610                            82610                 None
# 0082615                            82615                 None
# 0083202                            83202                 None
# 0083904                            83904                 None
# 0084605                            84605                 None
# 0087402                            87402                87402
# 382759                             82610                 None
# 382773                             83904                 None
# 382867                             84605                 None
# 382757                             82404                 None
# 382783                             87402                87402
# 382760                             82610                 None
# 382868                             84605                 None
# 382761                             82610                 None
# 382699                             82691                 None
#
#                                     institution_name_ja  \
# institution_niicode
# 0010101                                           北海道大学
# 0010102                                         北海道教育大学
# 0010103                                          室蘭工業大学
# 0010104                                          小樽商科大学
# 0010105                                          帯広畜産大学
# 0010106                                          北見工業大学
# 0010107                                          旭川医科大学
# 0011101                                            弘前大学
# 0011201                                            岩手大学
# 0011301                                            東北大学
# 0011302                                          宮城教育大学
# 0011401                                            秋田大学
# 0011501                                            山形大学
# 0011601                                            福島大学
# 0012101                                            茨城大学
# 0012201                                           宇都宮大学
# 0012301                                            群馬大学
# 0012401                                            埼玉大学
# 0012501                                            千葉大学
# 0012601                                            東京大学
# 0012602                                        東京医科歯科大学
# 0012603                                         東京外国語大学
# 0012604                                          東京学芸大学
# 0012605                                          東京農工大学
# 0012606                                          東京芸術大学
# 0012608                                          東京工業大学
# 0012610                                          東京水産大学
# 0012611                                        お茶の水女子大学
# 0012612                                          電気通信大学
# 0012613                                            一橋大学
# ...                                                 ...
# 0062612                                        大学入試センター
# 0062613                                    メディア教育開発センター
# 0062617                             国立オリンピック記念青少年総合センター
# 0062701                                     国立特殊教育総合研究所
# 0062702                                     大学評価・学位授与機構
# 0063901                                      岡崎国立共同研究機構
# 0064301                                       京都国立近代美術館
# 0064402                                         国立国際美術館
# 0064601                                         奈良国立博物館
# 0064602                                      奈良国立文化財研究所
# 0081402                                      秋田県高度技術研究所
# 0081403                                     秋田県工業技術センター
# 0082404                         国立身体障害者リハビリテーションセンター研究所
# 0082605                                    東京都神経科学総合研究所
# 0082608                                         国立多摩研究所
# 0082610                               国立病院医療センター(臨床研究部)
# 0082615                                        日本進路指導協会
# 0083202                                     富山市科学文化センター
# 0083904                               国立名古屋病院(臨床研究センター)
# 0084605                                     奈良県農業技術センター
# 0087402                                     熊本県工業技術センター
# 382759                                       国立国際医療センター
# 382773                  独立行政法人国立病院機構(名古屋医療センター臨床研究センター)
# 382867                                      奈良県農業総合センター
# 382757                          国立障害者リハビリテーションセンター(研究所)
# 382783               熊本県産業技術センター(ものづくり室、材料・地域資源室、食品加工室)
# 382760                               独立行政法人国立国際医療研究センター
# 382868                                    奈良県農業研究開発センター
# 382761                             国立研究開発法人国立国際医療研究センター
# 382699                             国際連合大学サステイナビリティ高等研究所
#
#                                                    institution_name_en
# institution_niicode
# 0010101                                            Hokkaido University
# 0010102                               Hokkaido University of Education
# 0010103                                Muroran Institute of Technology
# 0010104                                   Otaru University of Commerce
# 0010105              Obihiro University of Agriculture and Veterina...
# 0010106                                 Kitami Institute of Technology
# 0010107                                      Asahikawa Medical College
# 0011101                                            Hirosaki University
# 0011201                                               Iwate University
# 0011301                                              Tohoku University
# 0011302                                 Miyagi University of Education
# 0011401                                               Akita University
# 0011501                                            Yamagata University
# 0011601                                           Fukushima University
# 0012101                                             Ibaraki University
# 0012201                                          Utsunomiya University
# 0012301                                               Gunma University
# 0012401                                             Saitama University
# 0012501                                               Chiba University
# 0012601                                        The University of Tokyo
# 0012602                            Tokyo Medical and Dental University
# 0012603                            Tokyo University of Foreign Studies
# 0012604                                       Tokyo Gakugei University
# 0012605                 Tokyo University of Agriculture and Technology
# 0012606               Tokyo National University of Fine Arts and Music
# 0012608                                  Tokyo Institute of Technology
# 0012610                                                         東京水産大学
# 0012611                                          Ochanomizu University
# 0012612                       The University of Electro-Communications
# 0012613                                        Hitotsubashi University
# ...                                                                ...
# 0062612                 National Center Test for University Admissions
# 0062613                     National Institute of Multimedia Education
# 0062617              Youth Education National Olympics Memorial You...
# 0062701                  National Institute of Special Needs Education
# 0062702              National Institution for Academic Degrees and ...
# 0063901                           Okazaki National Research Institutes
# 0064301                       The National Museum of Modern Art, Kyoto
# 0064402                              The National Museum of Art, Osaka
# 0064601                                           Nara National Museum
# 0064602              Nara National Research Institute for Cultural ...
# 0081402              Akita Prefectural R&D Center, Akita Research I...
# 0081403              Akita Prefectural Institute Industrial Technology
# 0082404              Research Institute, National Rehabilitation Ce...
# 0082605                  Tokyo Metropolitan Institute for Neuroscience
# 0082608                        National Institute for Leprosy Research
# 0082610              Research Institute, International Medical Cent...
# 0082615                                                       日本進路指導協会
# 0083202                                ToyamaScience andCulture Center
# 0083904              Clinical research Center, Nagoya National Hosp...
# 0084605              The Nara Prefectural Agricultural Experiment S...
# 0087402                         Kumamoto Industrial Research Institute
# 382759               Research Institute, International Medical Cent...
# 382773               National Hospital Organization Nagoya Medical ...
# 382867                                                     奈良県農業総合センター
# 382757               National Rehabilitation Center for Persons wit...
# 382783                          Kumamoto Industrial Research Institute
# 382760               Research Institute, International Medical Cent...
# 382868               Nara Prefecture Agricultural Research and Deve...
# 382761                  National Center for Global Health and Medicine
# 382699                                            国際連合大学サステイナビリティ高等研究所
#
# [2806 rows x 4 columns]

# %%
# 外部キー制約を外す
try:
    with engine.connect() as con:
        con.execute("ALTER TABLE grantaward DROP FOREIGN KEY institution_niicode_1;")
except:
    pass
# データベースに書き込む
df.to_sql(
    "institutions",
    engine,
    if_exists="replace",
    dtype={
        "institution_niicode": Integer,
        "institution_mextcodei": String(255),
        "institution_jspscode": String(255),
    },
)
# Out:
# 2020-05-23 09:25:49,029 INFO sqlalchemy.engine.base.Engine ALTER TABLE grantaward DROP FOREIGN KEY institution_niicode_1;
# 2020-05-23 09:25:49,030 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,037 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:25:49,047 INFO sqlalchemy.engine.base.Engine DESCRIBE `institutions`
# 2020-05-23 09:25:49,048 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,052 INFO sqlalchemy.engine.base.Engine DESCRIBE `institutions`
# 2020-05-23 09:25:49,053 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,060 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `kaken`
# 2020-05-23 09:25:49,061 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,064 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `institutions`
# 2020-05-23 09:25:49,065 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,072 INFO sqlalchemy.engine.base.Engine
# DROP TABLE institutions
# 2020-05-23 09:25:49,073 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,079 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:25:49,084 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE institutions (
# 	institution_niicode INTEGER,
# 	institution_mextcode TEXT,
# 	institution_jspscode VARCHAR(255),
# 	institution_name_ja TEXT,
# 	institution_name_en TEXT
# )
#
#
# 2020-05-23 09:25:49,084 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,099 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:25:49,102 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_institutions_institution_niicode ON institutions (institution_niicode)
# 2020-05-23 09:25:49,103 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:25:49,109 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:25:49,114 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-23 09:25:49,143 INFO sqlalchemy.engine.base.Engine INSERT INTO institutions (institution_niicode, institution_mextcode, institution_jspscode, institution_name_ja, institution_name_en) VALUES (%(institution_niicode)s, %(institution_mextcode)s, %(institution_jspscode)s, %(institution_name_ja)s, %(institution_name_en)s)
# 2020-05-23 09:25:49,143 INFO sqlalchemy.engine.base.Engine ({'institution_niicode': '0010101', 'institution_mextcode': '10101', 'institution_jspscode': '10101', 'institution_name_ja': '北海道大学', 'institution_name_en': 'Hokkaido University'}, {'institution_niicode': '0010102', 'institution_mextcode': '10102', 'institution_jspscode': '10102', 'institution_name_ja': '北海道教育大学', 'institution_name_en': 'Hokkaido University of Education'}, {'institution_niicode': '0010103', 'institution_mextcode': '10103', 'institution_jspscode': '10103', 'institution_name_ja': '室蘭工業大学', 'institution_name_en': 'Muroran Institute of Technology'}, {'institution_niicode': '0010104', 'institution_mextcode': '10104', 'institution_jspscode': '10104', 'institution_name_ja': '小樽商科大学', 'institution_name_en': 'Otaru University of Commerce'}, {'institution_niicode': '0010105', 'institution_mextcode': '10105', 'institution_jspscode': '10105', 'institution_name_ja': '帯広畜産大学', 'institution_name_en': 'Obihiro University of Agriculture and Veterinary Medicine'}, {'institution_niicode': '0010106', 'institution_mextcode': '10106', 'institution_jspscode': '10106', 'institution_name_ja': '北見工業大学', 'institution_name_en': 'Kitami Institute of Technology'}, {'institution_niicode': '0010107', 'institution_mextcode': '10107', 'institution_jspscode': '10107', 'institution_name_ja': '旭川医科大学', 'institution_name_en': 'Asahikawa Medical College'}, {'institution_niicode': '0011101', 'institution_mextcode': '11101', 'institution_jspscode': '11101', 'institution_name_ja': '弘前大学', 'institution_name_en': 'Hirosaki University'}  ... displaying 10 of 2806 total bound parameter sets ...  {'institution_niicode': '382761', 'institution_mextcode': '82610', 'institution_jspscode': None, 'institution_name_ja': '国立研究開発法人国立国際医療研究センター', 'institution_name_en': 'National Center for Global Health and Medicine'}, {'institution_niicode': '382699', 'institution_mextcode': '82691', 'institution_jspscode': None, 'institution_name_ja': '国際連合大学サステイナビリティ高等研究所', 'institution_name_en': '国際連合大学サステイナビリティ高等研究所'})
# 2020-05-23 09:25:49,240 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ## 4. 審査区分マスタ

# %%
# XMLファイルからリストを作成する
tree = etree.parse("../grants_masterxml_kaken/review_section_master_kakenhi.xml")
review_sectionlist = []
for review_section_table in tree.iterfind("review_section_table"):
    review_section_table_type = review_section_table.get("type")
    review_section_table_start_date = review_section_table.get("start_date")
    review_section_table_end_date = review_section_table.get("end_date")
    # layer 1
    for review_section in review_section_table.iterfind("review_section"):
        review_section_path = review_section.get("path")
        review_section_niicode = review_section.find("code[@type='nii']").text
        review_section_name = review_section.find("name[@lang='ja']").text
        row = [
            review_section_table_type,
            review_section_table_start_date,
            review_section_table_end_date,
            review_section_path,
            review_section_niicode,
            review_section_name,
            1,
        ]
        review_sectionlist.append(row)
        # layer 2
        for review_section in review_section.iterfind("review_section"):
            review_section_path = review_section.get("path")
            review_section_niicode = review_section.find("code[@type='nii']").text
            review_section_name = review_section.find("name[@lang='ja']").text
            row = [
                review_section_table_type,
                review_section_table_start_date,
                review_section_table_end_date,
                review_section_path,
                review_section_niicode,
                review_section_name,
                2,
            ]
            review_sectionlist.append(row)
            # layer 3
            for review_section in review_section.iterfind("review_section"):
                review_section_path = review_section.get("path")
                review_section_niicode = review_section.find("code[@type='nii']").text
                review_section_name = review_section.find("name[@lang='ja']").text
                row = [
                    review_section_table_type,
                    review_section_table_start_date,
                    review_section_table_end_date,
                    review_section_path,
                    review_section_niicode,
                    review_section_name,
                    3,
                ]
                review_sectionlist.append(row)
# リストからデータフレームに変換する
columns = [
    "review_section_table_type",
    "review_section_table_start_date",
    "review_section_table_end_date",
    "review_section_path",
    "review_section_niicode",
    "review_section_name",
    "layer",
]
df = pd.DataFrame(review_sectionlist, columns=columns)
df
# Out:
#     review_section_table_type review_section_table_start_date  \
# 0              review_section                      2018-04-01
# 1              review_section                      2018-04-01
# 2              review_section                      2018-04-01
# 3              review_section                      2018-04-01
# 4              review_section                      2018-04-01
# 5              review_section                      2018-04-01
# 6              review_section                      2018-04-01
# 7              review_section                      2018-04-01
# 8              review_section                      2018-04-01
# 9              review_section                      2018-04-01
# 10             review_section                      2018-04-01
# 11             review_section                      2018-04-01
# 12             review_section                      2018-04-01
# 13             review_section                      2018-04-01
# 14             review_section                      2018-04-01
# 15             review_section                      2018-04-01
# 16             review_section                      2018-04-01
# 17             review_section                      2018-04-01
# 18             review_section                      2018-04-01
# 19             review_section                      2018-04-01
# 20             review_section                      2018-04-01
# 21             review_section                      2018-04-01
# 22             review_section                      2018-04-01
# 23             review_section                      2018-04-01
# 24             review_section                      2018-04-01
# 25             review_section                      2018-04-01
# 26             review_section                      2018-04-01
# 27             review_section                      2018-04-01
# 28             review_section                      2018-04-01
# 29             review_section                      2018-04-01
# ..                        ...                             ...
# 782     review_section_tokken                      2018-04-01
# 783     review_section_tokken                      2018-04-01
# 784     review_section_tokken                      2018-04-01
# 785     review_section_tokken                      2018-04-01
# 786     review_section_tokken                      2018-04-01
# 787     review_section_tokken                      2018-04-01
# 788     review_section_tokken                      2018-04-01
# 789     review_section_tokken                      2018-04-01
# 790     review_section_tokken                      2018-04-01
# 791     review_section_tokken                      2018-04-01
# 792     review_section_tokken                      2018-04-01
# 793     review_section_tokken                      2018-04-01
# 794     review_section_tokken                      2018-04-01
# 795     review_section_tokken                      2018-04-01
# 796     review_section_tokken                      2018-04-01
# 797     review_section_tokken                      2018-04-01
# 798     review_section_tokken                      2018-04-01
# 799     review_section_tokken                      2018-04-01
# 800     review_section_tokken                      2018-04-01
# 801     review_section_tokken                      2018-04-01
# 802     review_section_tokken                      2018-04-01
# 803     review_section_tokken                      2018-04-01
# 804     review_section_tokken                      2018-04-01
# 805     review_section_tokken                      2018-04-01
# 806     review_section_tokken                      2018-04-01
# 807     review_section_tokken                      2018-04-01
# 808     review_section_tokken                      2018-04-01
# 809     review_section_tokken                      2018-04-01
# 810     review_section_tokken                      2018-04-01
# 811     review_section_tokken                      2018-04-01
#
#     review_section_table_end_date review_section_path review_section_niicode  \
# 0                            None              000001                      1
# 1                            None        000001000002                      2
# 2                            None  000001000002000003                      3
# 3                            None  000001000002000004                      4
# 4                            None  000001000002000005                      5
# 5                            None  000001000002000006                      6
# 6                            None  000001000002000007                      7
# 7                            None  000001000002000008                      8
# 8                            None  000001000002000009                      9
# 9                            None  000001000002000010                     10
# 10                           None  000001000002000011                     11
# 11                           None        000001000012                     12
# 12                           None  000001000012000013                     13
# 13                           None  000001000012000014                     14
# 14                           None  000001000012000015                     15
# 15                           None  000001000012000016                     16
# 16                           None  000001000012000017                     17
# 17                           None  000001000012000018                     18
# 18                           None  000001000012000019                     19
# 19                           None  000001000012000020                     20
# 20                           None  000001000012000021                     21
# 21                           None  000001000012000022                     22
# 22                           None  000001000012000023                     23
# 23                           None        000001000024                     24
# 24                           None  000001000024000025                     25
# 25                           None  000001000024000026                     26
# 26                           None  000001000024000027                     27
# 27                           None  000001000024000028                     28
# 28                           None  000001000024000029                     29
# 29                           None  000001000024000030                     30
# ..                            ...                 ...                    ...
# 782                          None              000760                    760
# 783                          None              000761                    761
# 784                          None              000762                    762
# 785                          None              000763                    763
# 786                          None              000764                    764
# 787                          None              000765                    765
# 788                          None              000766                    766
# 789                          None              000767                    767
# 790                          None              000768                    768
# 791                          None              000769                    769
# 792                          None              000770                    770
# 793                          None              000771                    771
# 794                          None              000772                    772
# 795                          None              000773                    773
# 796                          None              000774                    774
# 797                          None              000775                    775
# 798                          None              000776                    776
# 799                          None              000777                    777
# 800                          None              000778                    778
# 801                          None              000779                    779
# 802                          None              000780                    780
# 803                          None              000781                    781
# 804                          None              000782                    782
# 805                          None              000783                    783
# 806                          None              000784                    784
# 807                          None              000785                    785
# 808                          None              000786                    786
# 809                          None              000787                    787
# 810                          None              000788                    788
# 811                          None              000789                    789
#
#                review_section_name  layer
# 0                             大区分A      1
# 1              中区分1:思想、芸術およびその関連分野      2
# 2              小区分01010:哲学および倫理学関連      3
# 3       小区分01020:中国哲学、印度哲学および仏教学関連      3
# 4                   小区分01030:宗教学関連      3
# 5                   小区分01040:思想史関連      3
# 6              小区分01050:美学および芸術論関連      3
# 7                   小区分01060:美術史関連      3
# 8                 小区分01070:芸術実践論関連      3
# 9         小区分01080:科学社会学および科学技術史関連      3
# 10                小区分90010:デザイン学関連      3
# 11            中区分2:文学、言語学およびその関連分野      2
# 12                 小区分02010:日本文学関連      3
# 13                 小区分02020:中国文学関連      3
# 14          小区分02030:英文学および英語圏文学関連      3
# 15              小区分02040:ヨーロッパ文学関連      3
# 16                 小区分02050:文学一般関連      3
# 17                  小区分02060:言語学関連      3
# 18                 小区分02070:日本語学関連      3
# 19                  小区分02080:英語学関連      3
# 20                小区分02090:日本語教育関連      3
# 21                小区分02100:外国語教育関連      3
# 22     小区分90020:図書館情報学および人文社会情報学関連      3
# 23      中区分3:歴史学、考古学、博物館学およびその関連分野      2
# 24                 小区分03010:史学一般関連      3
# 25                  小区分03020:日本史関連      3
# 26         小区分03030:アジア史およびアフリカ史関連      3
# 27       小区分03040:ヨーロッパ史およびアメリカ史関連      3
# 28                  小区分03050:考古学関連      3
# 29                小区分03060:文化財科学関連      3
# ..                             ...    ...
# 782               小区分61030:知能情報学関連      1
# 783        小区分61040:ソフトコンピューティング関連      1
# 784            小区分61050:知能ロボティクス関連      1
# 785               小区分61060:感性情報学関連      1
# 786       小区分62010:生命、健康および医療情報学関連      1
# 787    小区分62020:ウェブ情報学およびサービス情報学関連      1
# 788            小区分62030:学習支援システム関連      1
# 789  小区分62040:エンタテインメントおよびゲーム情報学関連      1
# 790              小区分63010:環境動態解析関連      1
# 791               小区分63020:放射線影響関連      1
# 792              小区分63030:化学物質影響関連      1
# 793              小区分63040:環境影響評価関連      1
# 794      小区分64010:環境負荷およびリスク評価管理関連      1
# 795   小区分64020:環境負荷低減技術および保全修復技術関連      1
# 796      小区分64030:環境材料およびリサイクル技術関連      1
# 797            小区分64040:自然共生システム関連      1
# 798           小区分64050:循環型社会システム関連      1
# 799      小区分64060:環境政策および環境配慮型社会関連      1
# 800                小区分80010:地域研究関連      1
# 801                 小区分80020:観光学関連      1
# 802               小区分80030:ジェンダー関連      1
# 803             小区分80040:量子ビーム科学関連      1
# 804               小区分90010:デザイン学関連      1
# 805    小区分90020:図書館情報学および人文社会情報学関連      1
# 806                小区分90030:認知科学関連      1
# 807               小区分90110:生体医工学関連      1
# 808               小区分90120:生体材料学関連      1
# 809              小区分90130:医用システム関連      1
# 810             小区分90140:医療技術評価学関連      1
# 811              小区分90150:医療福祉工学関連      1
#
# [812 rows x 7 columns]

# %%
# 外部キー制約を外す
try:
    with engine.connect() as con:
#        con.execute("ALTER TABLE grantaward DROP FOREIGN KEY review_section_niicode_1;")
        con.execute("ALTER TABLE grantaward_review_section DROP FOREIGN KEY fk_grantaward_review_section_review_section_niicode;")
except:
    pass
# データベースに書き込む
df.to_sql(
    "review_sections",
    engine,
    if_exists="replace",
    dtype={
        "review_section_table_type": String(255),
        "review_section_table_start_date": Date,
        "review_section_table_end_date": Date,
        "review_section_path": String(255),
        "review_section_niicode": Integer,
        "layer": Integer,
    },
)
# Out:
# 2020-05-23 09:26:10,066 INFO sqlalchemy.engine.base.Engine ALTER TABLE grantaward_review_section DROP FOREIGN KEY fk_grantaward_review_section_review_section_niicode;
# 2020-05-23 09:26:10,067 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,074 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-05-23 09:26:10,080 INFO sqlalchemy.engine.base.Engine DESCRIBE `review_sections`
# 2020-05-23 09:26:10,081 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,085 INFO sqlalchemy.engine.base.Engine DESCRIBE `review_sections`
# 2020-05-23 09:26:10,087 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,091 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `kaken`
# 2020-05-23 09:26:10,092 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,095 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `review_sections`
# 2020-05-23 09:26:10,096 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,102 INFO sqlalchemy.engine.base.Engine
# DROP TABLE review_sections
# 2020-05-23 09:26:10,103 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,107 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:10,113 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE review_sections (
# 	`index` BIGINT,
# 	review_section_table_type VARCHAR(255),
# 	review_section_table_start_date DATE,
# 	review_section_table_end_date DATE,
# 	review_section_path VARCHAR(255),
# 	review_section_niicode INTEGER,
# 	review_section_name TEXT,
# 	layer INTEGER
# )
#
#
# 2020-05-23 09:26:10,114 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,128 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:10,130 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_review_sections_index ON review_sections (`index`)
# 2020-05-23 09:26:10,130 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:10,136 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:10,140 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-23 09:26:10,152 INFO sqlalchemy.engine.base.Engine INSERT INTO review_sections (`index`, review_section_table_type, review_section_table_start_date, review_section_table_end_date, review_section_path, review_section_niicode, review_section_name, layer) VALUES (%(index)s, %(review_section_table_type)s, %(review_section_table_start_date)s, %(review_section_table_end_date)s, %(review_section_path)s, %(review_section_niicode)s, %(review_section_name)s, %(layer)s)
# 2020-05-23 09:26:10,153 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001', 'review_section_niicode': '1', 'review_section_name': '大区分A', 'layer': 1}, {'index': 1, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002', 'review_section_niicode': '2', 'review_section_name': '中区分1:思想、芸術およびその関連分野', 'layer': 2}, {'index': 2, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000003', 'review_section_niicode': '3', 'review_section_name': '小区分01010:哲学および倫理学関連', 'layer': 3}, {'index': 3, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000004', 'review_section_niicode': '4', 'review_section_name': '小区分01020:中国哲学、印度哲学および仏教学関連', 'layer': 3}, {'index': 4, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000005', 'review_section_niicode': '5', 'review_section_name': '小区分01030:宗教学関連', 'layer': 3}, {'index': 5, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000006', 'review_section_niicode': '6', 'review_section_name': '小区分01040:思想史関連', 'layer': 3}, {'index': 6, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000007', 'review_section_niicode': '7', 'review_section_name': '小区分01050:美学および芸術論関連', 'layer': 3}, {'index': 7, 'review_section_table_type': 'review_section', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000001000002000008', 'review_section_niicode': '8', 'review_section_name': '小区分01060:美術史関連', 'layer': 3}  ... displaying 10 of 812 total bound parameter sets ...  {'index': 810, 'review_section_table_type': 'review_section_tokken', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000788', 'review_section_niicode': '788', 'review_section_name': '小区分90140:医療技術評価学関連', 'layer': 1}, {'index': 811, 'review_section_table_type': 'review_section_tokken', 'review_section_table_start_date': '2018-04-01', 'review_section_table_end_date': None, 'review_section_path': '000789', 'review_section_niicode': '789', 'review_section_name': '小区分90150:医療福祉工学関連', 'layer': 1})
# 2020-05-23 09:26:10,195 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# 主キーと外部キー制約を設定する
with engine.connect() as con:
    con.execute("ALTER TABLE review_sections ADD INDEX (review_section_niicode);")
# Out:
# 2020-05-23 09:26:19,386 INFO sqlalchemy.engine.base.Engine ALTER TABLE review_sections ADD INDEX (review_section_niicode);
# 2020-05-23 09:26:19,388 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:19,400 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# # 5. 応募区分マスタ

# %%
# XMLファイルからリストを作成する
tree = etree.parse("../grants_masterxml_kaken/section_master_kakenhi.xml")
sectionlist = []
for section_table in tree.iterfind("section_table"):
    for section in section_table.iterfind("section"):
        section_name = section.find("name[@lang='ja']").text
        section_niicode = section.find("code[@type='nii']").text
        row = [section_niicode, section_name]
        sectionlist.append(row)
# リストをデータフレームに変換する
columns = ["section_niicode", "section_name"]
df = pd.DataFrame(sectionlist, columns=columns)
# 重複を削除して、category_niicodeに重複がないことを確認して、インデックスに設定する
df = df.drop_duplicates()
assert not df["section_niicode"].duplicated().any(), "section_niicode is duplicated."
df = df.set_index('section_niicode')
df
# Out:
#                 section_name
# section_niicode
# 1                        本調査
# 2                    成果とりまとめ
# 3                         総括
# 4                    学術定期刊行物
# 5                       学術図書
# 6                      二次刊行物
# 7                       現地調査
# 8                       調査総括
# 9                     がん特別調査
# 10                      現地調査
# 11                    二次刊行物等
# 12                      学術調査
# 13                      調査総括
# 14                   大学間協力研究
# 15                   データベース等
# 16                      共同研究
# 17                        一般
# 18                      展開研究
# 19                        総合
# 20                      企画調査
# 21                        試験
# 22                        時限
# 23                        国内
# 24                        外国
# 25                      海外学術
# 26                      特設分野

# %%
# 外部キー制約を外す
try:
    with engine.connect() as con:
        con.execute("ALTER TABLE grantaward DROP FOREIGN KEY section_niicode_1;")
except:
    pass
# データベースに書き込む
df.to_sql("sections", engine, if_exists="replace", dtype={"section_niicode": Integer})
# Out:
# 2020-05-23 09:26:28,766 INFO sqlalchemy.engine.base.Engine ALTER TABLE grantaward DROP FOREIGN KEY section_niicode_1;
# 2020-05-23 09:26:28,767 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,778 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:28,783 INFO sqlalchemy.engine.base.Engine DESCRIBE `sections`
# 2020-05-23 09:26:28,784 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,789 INFO sqlalchemy.engine.base.Engine DESCRIBE `sections`
# 2020-05-23 09:26:28,790 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,795 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `kaken`
# 2020-05-23 09:26:28,796 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,799 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `sections`
# 2020-05-23 09:26:28,801 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,804 INFO sqlalchemy.engine.base.Engine
# DROP TABLE sections
# 2020-05-23 09:26:28,806 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,810 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:28,813 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE sections (
# 	section_niicode INTEGER,
# 	section_name TEXT
# )
#
#
# 2020-05-23 09:26:28,814 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,826 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:28,827 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_sections_section_niicode ON sections (section_niicode)
# 2020-05-23 09:26:28,828 INFO sqlalchemy.engine.base.Engine {}
# 2020-05-23 09:26:28,834 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-05-23 09:26:28,838 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-05-23 09:26:28,840 INFO sqlalchemy.engine.base.Engine INSERT INTO sections (section_niicode, section_name) VALUES (%(section_niicode)s, %(section_name)s)
# 2020-05-23 09:26:28,841 INFO sqlalchemy.engine.base.Engine ({'section_niicode': '1', 'section_name': '本調査'}, {'section_niicode': '2', 'section_name': '成果とりまとめ'}, {'section_niicode': '3', 'section_name': '総括'}, {'section_niicode': '4', 'section_name': '学術定期刊行物'}, {'section_niicode': '5', 'section_name': '学術図書'}, {'section_niicode': '6', 'section_name': '二次刊行物'}, {'section_niicode': '7', 'section_name': '現地調査'}, {'section_niicode': '8', 'section_name': '調査総括'}  ... displaying 10 of 26 total bound parameter sets ...  {'section_niicode': '25', 'section_name': '海外学術'}, {'section_niicode': '26', 'section_name': '特設分野'})
# 2020-05-23 09:26:28,846 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ここまででマスタが完成
